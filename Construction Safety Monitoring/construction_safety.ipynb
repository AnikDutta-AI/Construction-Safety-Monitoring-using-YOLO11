# %%
# !nvidia-smi
# Out:
# Sun Aug 16 13:14:08 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# Install YOLO11 via Ultralytics

# %%
# %pip install "ultralytics<=8.3.40" supervision roboflow
# prevent ultralytics from tracking your activity
# !yolo settings sync=False
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.40 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 47.4/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="jPUrR0Cmix5elufW4KHQ")
project = rf.workspace("anik-dutta").project("construction-safety-qchsx-pqnoq")
version = project.version(1)
dataset = version.download("yolov11")

# %%
dataset.location

# %% [markdown]
# # Custom Training

# %%
# !yolo task=detect mode=train model=yolo11s.pt data={dataset.location}/data.yaml epochs=50 imgsz=640 plots=True

# %% [markdown]
# Confusion_matrix

# %%
Image("/content/runs/detect/train/confusion_matrix.png",width=600)

# %%
Image("/content/runs/detect/train/labels.jpg",width=600)

# %%
Image("/content/runs/detect/train/results.png",width=600)

# %%
Image("/content/runs/detect/train/labels.jpg",width=600)

# %%
Image("/content/runs/detect/train/val_batch0_labels.jpg",width=600)

# %%
Image("/content/runs/detect/train/val_batch2_labels.jpg",width=600)

# %% [markdown]
# Validate fine-tuned model

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml

# %% [markdown]
# Inference with custom model

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob(f'/content/runs/detect/predict'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[:3]:#will take randomly 3 image
    display(IPyImage(filename=img, width=600))
    print("\n")

# %%
from google.colab import files

uploaded = files.upload()

# %%
# !ls /content/images.jpeg

# %%
# !yolo task=detect mode=predict \
model=/content/runs/detect/train/weights/best.pt \
conf=0.25 \
source=/content/images.jpeg\
save=True

# %%
from google.colab import files

uploaded = files.upload()

# %%
# %ls /content/WhatsApp Video 2026-08-11 at 2.45.29 PM.mp4

# %%
# !yolo task=detect mode=predict \
model=/content/runs/detect/train/weights/best.pt \
conf=0.25 \
source="/content/WhatsApp Video 2026-08-11 at 2.45.29 PM.mp4"\
save=True

# %% [markdown]
# | Command  | Meaning                          |
# | -------- | -------------------------------- |
# | `ls`     | List files and folders           |
# | `ls -lh` | List files with readable sizes   |
# | `pwd`    | Show current directory           |
# | `cd`     | Change directory                 |
# | `mkdir`  | Create a folder                  |
# | `rmdir`  | Remove an empty folder           |
# | `cp`     | Copy a file/folder               |
# | `mv`     | Move or rename a file/folder     |
# | `rm`     | Delete a file                    |
# | `rm -r`  | Delete a folder and its contents |
# | `find`   | Find files/folders               |
# | `file`   | Check the type of a file         |
# | `du -sh` | Check folder/file size           |
# | `df -h`  | Check available disk space       |
